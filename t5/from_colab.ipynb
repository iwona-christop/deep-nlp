# %% [markdown]
# # Requirements

# %%
! pip install datasets evaluate transformers sacrebleu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 KB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 69.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 6.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # `wget`

# %%
! wget 'https://git.wmi.amu.edu.pl/s443930/deep-nlp/raw/branch/master/t5/data/test.json'
! wget 'https://git.wmi.amu.edu.pl/s443930/deep-nlp/raw/branch/master/t5/data/train.json'
! wget 'https://git.wmi.amu.edu.pl/s443930/deep-nlp/raw/branch/master/t5/data/valid.json'
! wget 'https://git.wmi.amu.edu.pl/s443930/deep-nlp/raw/branch/master/t5/run_translation.py'
# Out:
# --2023-02-13 23:05:48--  https://git.wmi.amu.edu.pl/s443930/deep-nlp/raw/branch/master/t5/data/test.json
# Resolving git.wmi.amu.edu.pl (git.wmi.amu.edu.pl)... 150.254.78.40
# Connecting to git.wmi.amu.edu.pl (git.wmi.amu.edu.pl)|150.254.78.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19751365 (19M) [text/plain]
# Saving to: ‘test.json’
#
# test.json           100%[===================>]  18.84M  1.99MB/s    in 9.9s
#
# 2023-02-13 23:05:59 (1.91 MB/s) - ‘test.json’ saved [19751365/19751365]
#
# --2023-02-13 23:05:59--  https://git.wmi.amu.edu.pl/s443930/deep-nlp/raw/branch/master/t5/data/train.json
# Resolving git.wmi.amu.edu.pl (git.wmi.amu.edu.pl)... 150.254.78.40
# Connecting to git.wmi.amu.edu.pl (git.wmi.amu.edu.pl)|150.254.78.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6403138 (6.1M) [text/plain]
# Saving to: ‘train.json’
#
# train.json          100%[===================>]   6.11M  2.11MB/s    in 2.9s
#
# ...

# %% [markdown]
# # `run_translation.py`

# %%
! python run_translation.py \
  --cache_dir .cache_training \
  --model_name_or_path "t5-small" \
  --freeze_weights \
  --train_file train.json \
  --validation_file valid.json \
  --test_file test.json \
  --per_device_train_batch_size 8 \
  --per_device_eval_batch_size 8 \
  --source_lang "text" \
  --target_lang "label" \
  --source_prefix "review classification" \
  --max_source_length 256 \
  --max_target_length 128 \
  --generation_max_length 128 \
  --do_train \
  --do_eval \
  --do_predict \
  --predict_with_generate \
  --max_eval_samples 2000 \
  --num_train_epochs 1 \
  --save_strategy steps \
  --save_steps 250 \
  --save_total_limit 5 \
  --logging_strategy steps \
  --logging_steps 100 \
  --eval_steps 250 \
  --evaluation_strategy steps \
  --metric_for_best_model accuracy \
  --greater_is_better True \
  --load_best_model_at_end True \
  --output_dir drive/MyDrive/t5 \
  --overwrite_output_dir
# Out:
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
#  79% 2756/3468 [03:56<00:56, 12.50it/s][INFO|configuration_utils.py:543] 2023-02-13 23:14:16,258 >> Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# [INFO|configuration_utils.py:543] 2023-02-13 23:14:16,341 >> Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
#  80% 2758/3468 [03:56<00:57, 12.31it/s][INFO|configuration_utils.py:543] 2023-02-13 23:14:16,424 >> Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# [INFO|configuration_utils.py:543] 2023-02-13 23:14:16,508 >> Generate config GenerationConfig {
# ...
